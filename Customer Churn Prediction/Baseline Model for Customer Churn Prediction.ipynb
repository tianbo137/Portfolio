# %% [markdown]
# # Baseline Model for Customer Churn Prediction

# %% [markdown]
# ## 1. Exploratory Data Analysis

# %%
# %bq tables list
# Out:
# <ul><li>dark-garden-296106.kkbox_bucket.ft_satisfaction</li><li>dark-garden-296106.kkbox_bucket.members</li><li>dark-garden-296106.kkbox_bucket.submission</li><li>dark-garden-296106.kkbox_bucket.submission2</li><li>dark-garden-296106.kkbox_bucket.train</li><li>dark-garden-296106.kkbox_bucket.transaction</li><li>dark-garden-296106.kkbox_bucket.user_label</li><li>dark-garden-296106.kkbox_bucket.user_label2</li><li>dark-garden-296106.kkbox_bucket.user_logs</li></ul>

# %%
# %bq tables view -n dark-garden-296106.kkbox_bucket.user_label2
# Out:
# BigQuery Table - name: dark-garden-296106.kkbox_bucket.user_label2

# %%
# %bq query -n check
# -- unique user, ratio of churn
SELECT COUNT(DISTINCT msno) AS uni_msno, COUNT(msno) AS not_null_msno,
       sum(CASE WHEN is_churn THEN 1 ELSE 0 END) AS churn_ratio
FROM `dark-garden-296106.kkbox_bucket.user_label2`

# %%
# %bq dryrun -q check
# Out:
#     <p>Dry run information:    41MB to process, results not cached</p>

# %%
# %bq execute -q check
# Out:
# QueryResultsTable job_k_YyUvTJ3LzKxw5P_01F2IMp-zFi

# %% [markdown]
# Therefore, there are 886500 customers and 4.9% of them are churners, therefore we will be dealing with **highly imbalanced dataset**. In the following, we import Python for more careful analysis of the training data.

# %%
# Python packages
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# ignore warning
import warnings
warnings.filterwarnings("ignore")

# %%
# Square scale
# https://stackoverflow.com/questions/42277989/square-root-scale-using-matplotlib-python
import matplotlib.scale as mscale
import matplotlib.pyplot as plt
import matplotlib.transforms as mtransforms
import matplotlib.ticker as ticker
import numpy as np

class SquareRootScale(mscale.ScaleBase):
    """
    ScaleBase class for generating square root scale.
    """

    name = 'squareroot'

    def __init__(self, axis, **kwargs):
        mscale.ScaleBase.__init__(self)

    def set_default_locators_and_formatters(self, axis):
        axis.set_major_locator(ticker.AutoLocator())
        axis.set_major_formatter(ticker.ScalarFormatter())
        axis.set_minor_locator(ticker.NullLocator())
        axis.set_minor_formatter(ticker.NullFormatter())

    def limit_range_for_scale(self, vmin, vmax, minpos):
        return  max(0., vmin), vmax

    class SquareRootTransform(mtransforms.Transform):
        input_dims = 1
        output_dims = 1
        is_separable = True

        def transform_non_affine(self, a): 
            return np.array(a)**0.5

        def inverted(self):
            return SquareRootScale.InvertedSquareRootTransform()

    class InvertedSquareRootTransform(mtransforms.Transform):
        input_dims = 1
        output_dims = 1
        is_separable = True

        def transform(self, a):
            return np.array(a)**2

        def inverted(self):
            return SquareRootScale.SquareRootTransform()

    def get_transform(self):
        return self.SquareRootTransform()

mscale.register_scale(SquareRootScale)
'''
fig, ax = plt.subplots(1)

ax.plot(np.arange(0, 9)**2, label='$y=x^2$')
ax.legend()

ax.set_yscale('squareroot')
ax.set_yticks(np.arange(0,9,2)**2)
ax.set_yticks(np.arange(0,8.5,0.5)**2, minor=True)

plt.show()
''';

# %% [markdown]
# We visualize the ratio of churners.

# %%
# Pandas
query = """ 
SELECT COUNT(msno) AS is_churn_count
FROM `dark-garden-296106.kkbox_bucket.user_label2`
GROUP BY is_churn
        """
df = pd.read_gbq(query,project_id='dark-garden-296106',dialect='standard')
# Out:
# Requesting query... ok.
# Job ID: f4a87ccd-0fd1-4486-b900-3c4e285f64ae
# Query running...
# Query done.
# Cache hit.
#
# Retrieving results...
# Got 2 rows.
#
# Total time taken 0.88 s.
# Finished at 2021-01-24 21:53:11.

# %%
# Give labels
df_is_churn = df.reset_index().rename(columns={'index':'labels'})
# Plot
ax = df_is_churn.plot(kind='bar', x='labels',y='is_churn_count',legend=False,figsize=(8,5))
plt.xticks(rotation=0)
ax.set_yscale('squareroot')
# Ticks the ratio
for p in ax.patches[:4]:
    ax.annotate('%.3f' % (p.get_height()/ df_is_churn.is_churn_count.sum()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
# %bq tables view -n dark-garden-296106.kkbox_bucket.user_logs
# Out:
# BigQuery Table - name: dark-garden-296106.kkbox_bucket.user_logs

# %%
# %bq query -n check
# -- uni, not_null, quantiles
SELECT COUNT(date) AS not_null_date, COUNT(num_25) AS not_null_25,COUNT(num_50) AS not_null_50,
       COUNT(num_75) AS not_null_75,COUNT(num_985) AS not_null_985,COUNT(num_100) AS not_null_100,
       COUNT(num_unq) AS not_null_nuq, COUNT(total_secs) AS not_null_total_secs
FROM `dark-garden-296106.kkbox_bucket.user_logs`

# %%
# %bq dryrun -q check
# Out:
#     <p>Dry run information:    26GB to process, results not cached</p>

# %%
# %bq execute -q check
# Out:
# QueryResultsTable job_eQf9mDfPKtKCS0yxecu96aUutUO_

# %% [markdown]
# There are no null values in the user_logs table. Now we check the distribution of the user log data.

# %%
# %bq query -n check
SELECT APPROX_QUANTILES(num_25,3) AS quant 
FROM `dark-garden-296106.kkbox_bucket.user_logs`
UNION ALL
SELECT APPROX_QUANTILES(num_50,3) AS quant
FROM `dark-garden-296106.kkbox_bucket.user_logs`

# %%
# %bq dryrun -q check
# Out:
#     <p>Dry run information:     6GB to process, results not cached</p>

# %%
# %bq execute -q check
# Out:
# QueryResultsTable job_iQV-kJ15wNYr3joLjvw5pTbHbSZ-

# %%
# %bq query -n check
# -- quantiles num ARRAY CTE dtyle = int64
WITH Quant_Num_ARRAY AS(
                   SELECT APPROX_QUANTILES(num_25,4) AS quant 
                   FROM `dark-garden-296106.kkbox_bucket.user_logs`      UNION ALL
                   SELECT APPROX_QUANTILES(num_50,4) AS quant 
                   FROM `dark-garden-296106.kkbox_bucket.user_logs`      UNION ALL 
                   SELECT APPROX_QUANTILES(num_75,4) AS quant 
                   FROM `dark-garden-296106.kkbox_bucket.user_logs`       UNION ALL 
                   SELECT APPROX_QUANTILES(num_985,4) AS quant 
                   FROM `dark-garden-296106.kkbox_bucket.user_logs`       UNION ALL
                   SELECT APPROX_QUANTILES(num_100,4) AS quant 
                   FROM `dark-garden-296106.kkbox_bucket.user_logs`       UNION ALL
                   SELECT APPROX_QUANTILES(num_unq,4) AS quant 
                   FROM `dark-garden-296106.kkbox_bucket.user_logs`)

# -- quantiles sec ARRAY CTE dtype = double
, Quant_Secs_ARRAY AS(
                   SELECT APPROX_QUANTILES(total_secs,4)  AS quant_secs 
                   FROM `dark-garden-296106.kkbox_bucket.user_logs`)

SELECT quant[OFFSET(0)] AS min, quant[OFFSET(1)] AS Q1,
       quant[OFFSET(2)] AS Q2,  quant[OFFSET(3)] AS Q4,
       quant[OFFSET(4)] AS max
FROM Quant_Num_ARRAY

UNION ALL

SELECT ROUND(quant_secs[OFFSET(0)]) AS min, ROUND(quant_secs[OFFSET(1)]) AS Q1,
       ROUND(quant_secs[OFFSET(2)]) AS Q2,  ROUND(quant_secs[OFFSET(3)]) AS Q4,
       ROUND(quant_secs[OFFSET(4)]) AS max
FROM Quant_Secs_ARRAY

# %%
# %bq dryrun -q check
# Out:
#     <p>Dry run information:    22GB to process, results not cached</p>

# %%
# Alternative way to get describe_dataframe instead of using read_gbq
df_describe = %bq execute -q check --to-dataframe
# assign feature name
df_describe.insert(loc=0,column='feature',
          value=['num_50','num_25','num_75','num_985','num_100','num_unq','total_sec'])

# show it clearly
pd.set_option('display.float_format', lambda x: '%.1f' % x)
df_describe = df_describe.reindex(index=[1,0,2,3,4,5,6])
df_describe
# Out:
#      feature                 min     Q1     Q2      Q4                max
# 1     num_25                 0.0    0.0    2.0     7.0            18798.0
# 0     num_50                 1.0    8.0   19.0    40.0             4925.0
# 2     num_75                 0.0    0.0    0.0     1.0             2747.0
# 3    num_985                 0.0    0.0    1.0     2.0             1710.0
# 4    num_100                 0.0    6.0   17.0    38.0            42004.0
# 5    num_unq                 0.0    0.0    0.0     1.0             1690.0
# 6  total_sec -9223372036854776.0 1905.0 4604.0 10154.0 9223372036854776.0

# %% [markdown]
# ### A. Training Data

# %%
# %bq query -n query 
-- user_latent_satisfaction CTE
WITH feature AS(
                SELECT msno, AVG(single_day_latent_satisfaction) AS user_latent_satisfaction
                FROM( 
                     SELECT msno, ( num_100 / (num_25 + num_50 + num_75 + num_985 + num_100) ) AS single_day_latent_satisfaction
                     FROM `dark-garden-296106.kkbox_bucket.user_logs`
                     WHERE date > 20160901 AND date < 20170228 )
                GROUP BY msno)
SELECT train.msno, feature.user_latent_satisfaction
FROM `dark-garden-296106.kkbox_bucket.user_label2` AS train
LEFT JOIN feature
ON  train.msno = feature.msno

# %%
# %bq dryrun -q query
# Out:
#     <p>Dry run information:    38GB to process, results not cached</p>

# %%
# %bq extract -f csv -H -p 'gs://kkbox_bucket/ft_satisfaction.csv' -q query --verbose
# Out:
# Job dark-garden-296106/job_ql1X3OEIiUv5n3_nEk-JsNdsY09f completed

# %%
# storage
from google.datalab import Context
import google.datalab.bigquery as bq
try:
  from StringIO import StringIO
except ImportError:
  from io import BytesIO as StringIO

# %%
# %gcs read --object gs://kkbox_bucket/ft_satisfaction.csv -v df_ft_satis

# %%
df_ft_satis = pd.read_csv(StringIO(df_ft_satis))
df_ft_satis.head()
# Out:
#                                            msno  user_latent_satisfaction
# 0  2TR1WJSkJG1t8qqlzFipq0k5yLDp4T1/mju9Pq1DCxM=                       0.4
# 1  2a/AFquZC7oEjaW+2c3d1iMk28ZM+z4Iwo4kDFl89Lc=                       0.8
# 2  3ERFxYptx7DBL5KKLQYf8+XBkwizIpjNnPkQmmsa6Is=                       0.7
# 3  D6lXFNXODF8RtCaWfukd8RmW36KskenabNU+n9c7LKM=                       0.7
# 4  IDy7GFv0RKd9zObB5qoUUHEMGcHORiJnTHXOLioW3Ds=                       0.7

# %%
# %bq query -n query
-- day_listen CTE
WITH features AS (
                   SELECT  msno AS msno , COUNT(msno) AS day_listen
                   FROM `dark-garden-296106.kkbox_bucket.user_logs`
                   WHERE date > 20160901 AND date < 20170228 
                   GROUP BY msno)
SELECT train.msno, train.is_churn, features.day_listen
FROM `dark-garden-296106.kkbox_bucket.user_label2` AS train
LEFT JOIN features 
        ON   train.msno = features.msno

# %%
# %bq dryrun -q query
# Out:
#     <p>Dry run information:    22GB to process, results not cached</p>

# %%
# %bq extract -f csv -H -p 'gs://kkbox_bucket/ft_day_listen.csv' -q query --verbose
# Out:
# Job dark-garden-296106/job_Bx-kOn37jicP0B2dVzh-BCMdGfCO completed

# %%
# %gcs read --object gs://kkbox_bucket/ft_day_listen.csv -v df_ft_day_listen

# %%
df_ft_day_listen = pd.read_csv(StringIO(df_ft_day_listen))

# %%
df_ft_day_listen.head()
# Out:
#                                            msno  is_churn  day_listen
# 0  2wJJToqAXFTdG1wP8qmQhsv6dJlj4Jr4ZCFhp0ZEVVI=     False       135.0
# 1  3/jv0QbKYn+W+bhSA9ZaMgHv9fpYivo2aiP8hIJPfUQ=     False       137.0
# 2  6nyAb4oFlm2yQ7XooMqjwSY+BJhRHN8VCRl2dgf3+fA=     False        38.0
# 3  BtQP2kyMWYmfyiXjttWNoqygnb2hMhN6qbZ8cGo9pD0=     False       103.0
# 4  CRrNBvDX9zkRTWsKlr8AyWKCCRynsqPW6ptSdnBCXTQ=     False        55.0

# %%
df_ft_satis.head()
# Out:
#                                            msno  user_latent_satisfaction
# 0  2TR1WJSkJG1t8qqlzFipq0k5yLDp4T1/mju9Pq1DCxM=                       0.4
# 1  2a/AFquZC7oEjaW+2c3d1iMk28ZM+z4Iwo4kDFl89Lc=                       0.8
# 2  3ERFxYptx7DBL5KKLQYf8+XBkwizIpjNnPkQmmsa6Is=                       0.7
# 3  D6lXFNXODF8RtCaWfukd8RmW36KskenabNU+n9c7LKM=                       0.7
# 4  IDy7GFv0RKd9zObB5qoUUHEMGcHORiJnTHXOLioW3Ds=                       0.7

# %%
df_train = pd.merge(df_ft_day_listen, df_ft_satis, how='left',on=['msno'])

# %%
df_train.head()
# Out:
#                                            msno  is_churn  day_listen  \
# 0  2wJJToqAXFTdG1wP8qmQhsv6dJlj4Jr4ZCFhp0ZEVVI=     False       135.0
# 1  3/jv0QbKYn+W+bhSA9ZaMgHv9fpYivo2aiP8hIJPfUQ=     False       137.0
# 2  6nyAb4oFlm2yQ7XooMqjwSY+BJhRHN8VCRl2dgf3+fA=     False        38.0
# 3  BtQP2kyMWYmfyiXjttWNoqygnb2hMhN6qbZ8cGo9pD0=     False       103.0
# 4  CRrNBvDX9zkRTWsKlr8AyWKCCRynsqPW6ptSdnBCXTQ=     False        55.0
#
#    user_latent_satisfaction
# 0                       0.7
# 1                       0.6
# 2                       0.9
# 3                       0.8
# 4                       0.9

# %% [markdown]
# ### B. Testing Data

# %%
# %bq query -n query
-- user_latent_satisfaction CTE
WITH feature AS(
                SELECT msno, AVG(single_day_latent_satisfaction) AS user_latent_satisfaction
                FROM( 
                     SELECT msno, ( num_100 / (num_25 + num_50 + num_75 + num_985 + num_100) ) AS single_day_latent_satisfaction
                     FROM `dark-garden-296106.kkbox_bucket.user_logs`
                     WHERE date > 20161001 AND date < 20170331 )
                GROUP BY msno)
SELECT sub.msno, feature.user_latent_satisfaction
FROM `dark-garden-296106.kkbox_bucket.submission` AS sub
LEFT JOIN feature
ON  sub.msno = feature.msno

# %%
# %bq dryrun -q query
# Out:
#     <p>Dry run information:    38GB to process, results not cached</p>

# %%
# to storage then read 
# ~ 18s
# %bq extract -f csv -H -p 'gs://kkbox_bucket/sub_ft_satisfaction.csv' -q query --verbose
# Out:
# Job dark-garden-296106/job_9N0Nf3dx1E3XqeepJf8H4CMctjQ4 completed

# %%
# %bq query -n query
WITH features AS (
                   SELECT  msno AS msno , COUNT(msno) AS day_listen
                   FROM `dark-garden-296106.kkbox_bucket.user_logs`
                   -- Filter 20160201 , 20170228
                   WHERE date > 20161001 AND date < 20170331 
                   GROUP BY msno)
SELECT sub.msno, sub.is_churn, features.day_listen
FROM `dark-garden-296106.kkbox_bucket.submission` AS sub
LEFT JOIN features 
        ON   sub.msno = features.msno

# %%
# %bq dryrun -q query
# Out:
#     <p>Dry run information:    22GB to process, results not cached</p>

# %%
# to storage then read 
# ~ 18s
# %bq extract -f csv -H -p 'gs://kkbox_bucket/sub_ft_day_listen.csv' -q query --verbose
# Out:
# Job dark-garden-296106/job_dmyx7hbyUpL4ga99-ekvgHlE9iYa completed

# %%
# del df_sub, df_sub_ft_satis, df_sub_ft_day_listen

# %%
# ~ 1.5 s 
# %gcs read --object gs://kkbox_bucket/sub_ft_satisfaction.csv -v df_sub_ft_satis

# %%
# ~ 1.5 s 
# %gcs read --object gs://kkbox_bucket/sub_ft_day_listen.csv -v df_sub_ft_day_listen

# %%
df_sub_ft_day_listen = pd.read_csv(StringIO(df_sub_ft_day_listen))
df_sub_ft_satis = pd.read_csv(StringIO(df_sub_ft_satis))

# %%
df_sub = pd.merge(df_sub_ft_day_listen, df_sub_ft_satis, how='left',on=['msno'])
df_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 970960 entries, 0 to 970959
# Data columns (total 4 columns):
# msno                        970960 non-null object
# is_churn                    970960 non-null int64
# day_listen                  813832 non-null float64
# user_latent_satisfaction    813832 non-null float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 37.0+ MB

# %%
df_sub.head()
# Out:
#                                            msno  is_churn  day_listen  \
# 0  6OlZbbgM+0PjnShnk82ORhLuBaqn6m0bv+I/x9bpmHs=         0        25.0
# 1  r5Wy36Qxv+4oGLPdsW77V7sZxl26ZWuhGS/Rqeq6Ylo=         0        20.0
# 2  04Mn5oun4VJEKGLCfYpCThMsAK7rgr6vqdaVHjWIc3o=         0        62.0
# 3  epHu5TBNB/rfde3mFom9ggqbE0dIiIkNePK+NjQhBT0=         0        35.0
# 4  mCIKnFAnwKACQYcyk2rE+kXuH+1P8KAhrsK7On4fnIc=         0        10.0
#
#    user_latent_satisfaction
# 0                       0.7
# 1                       0.6
# 2                       0.3
# 3                       0.8
# 4                       0.4

# %% [markdown]
# ### C. Basic EDA

# %%
sns.set(font_scale=1.56)
sns.pairplot(df_train.dropna(),vars=['day_listen','user_latent_satisfaction'],\
             diag_kind='kde',hue='is_churn',plot_kws = {'alpha': 0.4, 's': 80},size = 4)

# %%
# heat map 
corr_matrix = df_train[['day_listen','user_latent_satisfaction','is_churn']].corr()
mask = np.zeros_like(corr_matrix)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style('dark'):
  fig, ax = plt.subplots(figsize=(8,6))
  corr_map = sns.heatmap(corr_matrix,mask=mask,annot=True,ax=ax)
  plt.xticks(rotation=-15
            )

# %% [markdown]
# * As we can see, churn rate is higher for those with less day_listen
# * From statistical aspect, higher user_latent_satisfaction indicates lower churn rate, but surprisingly when user_latent_satisfaction = 0, churn rate is acturally lower
# * Both features are not very related to churn rate, maybe due to the noise. We can binarize the data to overcome this

# %% [markdown]
# ### D. Missing Value

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
print('training set:')
print(''*60)
print(df_train.isnull().sum() / len(df_train))
print('_'*60)
print('testing set:')
print(''*60)
print(df_sub.isnull().sum() / len(df_sub))
# Out:
# training set:
#
# msno                       0.000
# is_churn                   0.000
# day_listen                 0.173
# user_latent_satisfaction   0.173
# dtype: float64
# ____________________________________________________________
# testing set:
#
# msno                       0.000
# is_churn                   0.000
# day_listen                 0.162
# user_latent_satisfaction   0.162
# dtype: float64

# %% [markdown]
# ### E. Binarization of Day_listen

# %%
# filling na with -1
df_train[['day_listen','user_latent_satisfaction']] = df_train[['day_listen','user_latent_satisfaction']].fillna(-1)
df_sub[['day_listen','user_latent_satisfaction']] = df_sub[['day_listen','user_latent_satisfaction']].fillna(-1)
# place nan in testing set
df_sub['is_churn'] = np.nan
# combine 
df_data = df_train.append(df_sub)

# %%
# training set 
# df_data[:len(df_train)].is_churn.isnull().any()
# testing set 
# (df_data[len(df_train):].is_churn == -1).all() 
# df_train, df_sub = df_data[:len(df_train)], df_data[len(df_train):]

# %%
# cut into bins
bins = 4

df_data.loc[(df_data.day_listen >= 0),'day_listen_level'] = pd.cut(df_data.loc[(df_data.day_listen >= 0),'day_listen'], bins,labels=[1,2,3,4])
df_data.day_listen_level = df_data.day_listen_level.fillna(-1)

# prepare table (% of each value)
from pandas.plotting import table
df_percent = pd.DataFrame( df_data.day_listen_level.value_counts().sort_index() / len(df_data) ).round(3) 

# distribution

with sns.axes_style('white'):
  fig, [ax1,ax2] = plt.subplots(1,2, figsize=(25,10))
  sns.distplot(df_data.loc[(df_data.is_churn == 0) & (df_data.day_listen >= 0), 'day_listen'],kde=False, bins=bins, label='NOT_churn',ax=ax1,norm_hist=True)
  sns.distplot(df_data.loc[(df_data.is_churn == 1)& (df_data.day_listen >= 0), 'day_listen'],kde=False, bins=bins, label='churn',ax=ax1,norm_hist=True)
  ax1.legend()
  
# barplot with churn_rate plus df_percent table
  sns.barplot(x='day_listen_level', y='is_churn', data=df_data,ax=ax2,alpha=.75)
  ax2.axhline(0.049,linestyle='dashed',c='black',alpha=.3)
  table(ax2, df_percent,bbox=[0.80, 0.72, 0.2, 0.27])

# %% [markdown]
# ## 2. Baseline Model Training and Testing

# %%
df_train, df_sub = df_data[:len(df_train)], df_data[len(df_train):]

# ML
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
import xgboost as xgb

print(df_train.columns)
print(df_sub.columns)
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Index(['msno', 'is_churn', 'day_listen', 'user_latent_satisfaction',
#        'day_listen_level'],
#       dtype='object')
# Index(['msno', 'is_churn', 'day_listen', 'user_latent_satisfaction',
#        'day_listen_level'],
#       dtype='object')

# %%
day_lis_bins = ['msno','day_listen_level','is_churn']
day_lis = ['msno','day_listen','is_churn']

# %%
def model_training_rf(training_data,testing_data):
  # splits train and validation set
  X = training_data.drop(labels=['msno','is_churn'],axis=1)
  Y = training_data['is_churn']
  X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.2,random_state = 2)
  # Training ~ 01:45s
  model = RandomForestClassifier(random_state=2,n_estimators=300,
                           min_samples_split=0.05,n_jobs=-1,class_weight={0 :0.45,1 :0.55})
  model.fit(X_train,Y_train)
  
  # caculating E_val

  model_probs = model.predict_proba(X_val)
    # [:,1] to show the prob to is_churn = 1
  model_val_score = log_loss(Y_val,model_probs[:,1])
  
  # predict on testing set
  model_pred_testing_set = model.predict_proba(testing_data.drop(labels=['msno','is_churn'],axis=1))
  model_pred_testing_set = model_pred_testing_set[:,1] # take out the prob if is_churn = 1
  submission = pd.DataFrame({"msno": testing_data.msno})
  submission.insert(1,column='is_churn',value=model_pred_testing_set)
  
  return model, model_val_score, submission

# %%
orginal_day_listen_model, orginal_day_listen_val_score,\
orginal_day_listen_pred = model_training_rf(df_train[day_lis],df_sub[day_lis])

day_listen_bins_model, day_listen_bins_val_score,\
day_listen_bins_pred = model_training_rf(df_train[day_lis_bins],df_sub[day_lis_bins])

# %%
# saving result and committing

orginal_day_listen_pred.to_csv("/content/datalab/sub_orginal_day_listen_pred.csv", index=False)

# !gsutil cp '/content/datalab/sub_orginal_day_listen_pred.csv' 'gs://kkbox_bucket/submission/sub_orginal_day_listen_pred.csv';


day_listen_bins_pred.to_csv("/content/datalab/sub_day_listen_bins_pred.csv", index=False)

# !gsutil cp '/content/datalab/sub_day_listen_bins_pred.csv' 'gs://kkbox_bucket/submission/sub_day_listen_bins_pred.csv';
# Out:
# Copying file:///content/datalab/sub_orginal_day_listen_pred.csv [Content-Type=text/csv]...
# \ [1 files][ 60.3 MiB/ 60.3 MiB]
# Operation completed over 1 objects/60.3 MiB.
# Copying file:///content/datalab/sub_day_listen_bins_pred.csv [Content-Type=text/csv]...
# \ [1 files][ 60.1 MiB/ 60.1 MiB]
# Operation completed over 1 objects/60.1 MiB.

# %%
pd.set_option('display.float_format', lambda x: '%.6f' % x)
df_score = pd.DataFrame({'Original':[np.around(orginal_day_listen_val_score,decimals=6),0.16044],
                             'Bins':[np.around(day_listen_bins_val_score,decimals=6),0.16049]})
df_score.index=['Val_score','Pub_score']

# without bins
orginal_day_listen_pred_plotting = orginal_day_listen_pred
orginal_day_listen_pred_plotting['orginal_idx'] = orginal_day_listen_pred_plotting.index

# bins 
day_listen_bins_pred_plotting = day_listen_bins_pred
day_listen_bins_pred_plotting['orginal_idx'] = day_listen_bins_pred_plotting.index

#plot
with sns.axes_style('white'):
  fig, ax = plt.subplots(figsize=(12,10))
  orginal_day_listen_pred_plotting.plot(kind='line',x='orginal_idx',y='is_churn',ax=ax,label='orginal')
  day_listen_bins_pred_plotting.plot(kind='line',x='orginal_idx',y='is_churn',ax=ax,alpha=.7,label='bins',title='Original vs Bins using RF')
  table(ax, df_score,bbox=[0.80, 0.60, 0.2, 0.27])

# %% [markdown]
# # User_latent_satisfaction

# %%
fig,ax = plt.subplots( figsize=(12,8))
sns.distplot(df_data.loc[(df_data.is_churn == 0) & (df_data.day_listen >= 0), 'user_latent_satisfaction'],kde=False,label='NOT_churn',ax=ax,norm_hist=True)
sns.distplot(df_data.loc[(df_data.is_churn == 1) & (df_data.day_listen >= 0), 'user_latent_satisfaction'],kde=False,label='churn',ax=ax,norm_hist=True)
ax.legend()
ax.axvline(0.75,linestyle='dashed',c='black',alpha=.3)
ax.axvline(0.72,linestyle='dashed',c='black',alpha=.3)

# %% [markdown]
# # Model Testing

# %%
satis = ['msno','day_listen','is_churn','user_latent_satisfaction']

# %%
satis_model, satis_val_score,\
satis_pred = model_training_rf(df_train[satis],df_sub[satis])

# %%
# saving result and committing

satis_pred.to_csv("/content/datalab/sub_satis_pred.csv", index=False)

# !gsutil cp '/content/datalab/sub_satis_pred.csv' 'gs://kkbox_bucket/submission/sub_satis_pred.csv';
# Out:
# Copying file:///content/datalab/sub_satis_pred.csv [Content-Type=text/csv]...
# \ [1 files][ 60.2 MiB/ 60.2 MiB]
# Operation completed over 1 objects/60.2 MiB.

# %%
print('val_log_loss:', np.around(satis_val_score,decimals=6))
print('pub_log_loss:', 0.15693)
# Out:
# val_log_loss: 0.192458
# pub_log_loss: 0.15693
